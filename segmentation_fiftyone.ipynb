# %%
from ultralytics import YOLO
seg_model = YOLO("[model].pt")
results = seg_model("vid8/test/images")
# Out:
# image 1/90 d:\fiftyone\vid8\test\images\frame_000006.PNG: 384x640 2 cars, 199.9ms
# image 2/90 d:\fiftyone\vid8\test\images\frame_000009.PNG: 384x640 2 cars, 156.7ms
# image 3/90 d:\fiftyone\vid8\test\images\frame_000010.PNG: 384x640 2 cars, 185.9ms
# image 4/90 d:\fiftyone\vid8\test\images\frame_000018.PNG: 384x640 2 cars, 182.4ms
# image 5/90 d:\fiftyone\vid8\test\images\frame_000038.PNG: 384x640 2 cars, 237.9ms
# image 6/90 d:\fiftyone\vid8\test\images\frame_000045.PNG: 384x640 2 cars, 227.9ms
# image 7/90 d:\fiftyone\vid8\test\images\frame_000055.PNG: 384x640 3 cars, 160.1ms
# image 8/90 d:\fiftyone\vid8\test\images\frame_000066.PNG: 384x640 2 cars, 185.5ms
# image 9/90 d:\fiftyone\vid8\test\images\frame_000076.PNG: 384x640 3 cars, 184.0ms
# image 10/90 d:\fiftyone\vid8\test\images\frame_000099.PNG: 384x640 2 cars, 174.8ms
# image 11/90 d:\fiftyone\vid8\test\images\frame_000101.PNG: 384x640 1 car, 153.8ms
# image 12/90 d:\fiftyone\vid8\test\images\frame_000104.PNG: 384x640 1 car, 178.8ms
# image 13/90 d:\fiftyone\vid8\test\images\frame_000120.PNG: 384x640 1 car, 181.7ms
# image 14/90 d:\fiftyone\vid8\test\images\frame_000170.PNG: 384x640 3 cars, 178.8ms
# image 15/90 d:\fiftyone\vid8\test\images\frame_000189.PNG: 384x640 3 cars, 237.9ms
# image 16/90 d:\fiftyone\vid8\test\images\frame_000194.PNG: 384x640 3 cars, 168.3ms
# image 17/90 d:\fiftyone\vid8\test\images\frame_000196.PNG: 384x640 3 cars, 167.3ms
# image 18/90 d:\fiftyone\vid8\test\images\frame_000210.PNG: 384x640 3 cars, 160.7ms
# image 19/90 d:\fiftyone\vid8\test\images\frame_000212.PNG: 384x640 2 cars, 163.3ms
# image 20/90 d:\fiftyone\vid8\test\images\frame_000220.PNG: 384x640 3 cars, 163.3ms
# image 21/90 d:\fiftyone\vid8\test\images\frame_000223.PNG: 384x640 3 cars, 155.4ms
# image 22/90 d:\fiftyone\vid8\test\images\frame_000228.PNG: 384x640 3 cars, 160.6ms
# image 23/90 d:\fiftyone\vid8\test\images\frame_000229.PNG: 384x640 3 cars, 178.8ms
# image 24/90 d:\fiftyone\vid8\test\images\frame_000233.PNG: 384x640 3 cars, 185.1ms
# image 25/90 d:\fiftyone\vid8\test\images\frame_000269.PNG: 384x640 2 cars, 183.0ms
# image 26/90 d:\fiftyone\vid8\test\images\frame_000294.PNG: 384x640 3 cars, 156.2ms
# image 27/90 d:\fiftyone\vid8\test\images\frame_000319.PNG: 384x640 4 cars, 185.6ms
# image 28/90 d:\fiftyone\vid8\test\images\frame_000321.PNG: 384x640 4 cars, 171.7ms
# image 29/90 d:\fiftyone\vid8\test\images\frame_000323.PNG: 384x640 4 cars, 177.0ms
# image 30/90 d:\fiftyone\vid8\test\images\frame_000326.PNG: 384x640 4 cars, 213.6ms
# image 31/90 d:\fiftyone\vid8\test\images\frame_000334.PNG: 384x640 4 cars, 241.6ms
# image 32/90 d:\fiftyone\vid8\test\images\frame_000355.PNG: 384x640 3 cars, 260.2ms
# image 33/90 d:\fiftyone\vid8\test\images\frame_000369.PNG: 384x640 3 cars, 199.8ms
# image 34/90 d:\fiftyone\vid8\test\images\frame_000374.PNG: 384x640 3 cars, 177.2ms
# image 35/90 d:\fiftyone\vid8\test\images\frame_000380.PNG: 384x640 3 cars, 164.6ms
# image 36/90 d:\fiftyone\vid8\test\images\frame_000401.PNG: 384x640 2 cars, 161.4ms
# image 37/90 d:\fiftyone\vid8\test\images\frame_000422.PNG: 384x640 2 cars, 156.7ms
# image 38/90 d:\fiftyone\vid8\test\images\frame_000427.PNG: 384x640 2 cars, 149.1ms
# image 39/90 d:\fiftyone\vid8\test\images\frame_000430.PNG: 384x640 1 car, 172.3ms
# image 40/90 d:\fiftyone\vid8\test\images\frame_000435.PNG: 384x640 1 car, 168.5ms
# image 41/90 d:\fiftyone\vid8\test\images\frame_000438.PNG: 384x640 1 car, 156.7ms
# image 42/90 d:\fiftyone\vid8\test\images\frame_000440.PNG: 384x640 1 car, 167.0ms
# image 43/90 d:\fiftyone\vid8\test\images\frame_000489.PNG: 384x640 1 car, 156.1ms
# image 44/90 d:\fiftyone\vid8\test\images\frame_000504.PNG: 384x640 2 cars, 162.4ms
# image 45/90 d:\fiftyone\vid8\test\images\frame_000508.PNG: 384x640 3 cars, 172.7ms
# image 46/90 d:\fiftyone\vid8\test\images\frame_000510.PNG: 384x640 2 cars, 165.7ms
# image 47/90 d:\fiftyone\vid8\test\images\frame_000525.PNG: 384x640 3 cars, 166.7ms
# image 48/90 d:\fiftyone\vid8\test\images\frame_000528.PNG: 384x640 2 cars, 183.8ms
# image 49/90 d:\fiftyone\vid8\test\images\frame_000535.PNG: 384x640 2 cars, 172.2ms
# image 50/90 d:\fiftyone\vid8\test\images\frame_000536.PNG: 384x640 2 cars, 171.8ms
# image 51/90 d:\fiftyone\vid8\test\images\frame_000545.PNG: 384x640 2 cars, 189.9ms
# image 52/90 d:\fiftyone\vid8\test\images\frame_000546.PNG: 384x640 2 cars, 165.3ms
# image 53/90 d:\fiftyone\vid8\test\images\frame_000550.PNG: 384x640 2 cars, 167.2ms
# image 54/90 d:\fiftyone\vid8\test\images\frame_000556.PNG: 384x640 1 car, 156.7ms
# image 55/90 d:\fiftyone\vid8\test\images\frame_000567.PNG: 384x640 1 car, 164.6ms
# image 56/90 d:\fiftyone\vid8\test\images\frame_000586.PNG: 384x640 1 car, 175.0ms
# image 57/90 d:\fiftyone\vid8\test\images\frame_000597.PNG: 384x640 1 car, 172.7ms
# image 58/90 d:\fiftyone\vid8\test\images\frame_000601.PNG: 384x640 1 car, 225.8ms
# image 59/90 d:\fiftyone\vid8\test\images\frame_000608.PNG: 384x640 1 car, 188.3ms
# image 60/90 d:\fiftyone\vid8\test\images\frame_000617.PNG: 384x640 1 car, 171.5ms
# image 61/90 d:\fiftyone\vid8\test\images\frame_000644.PNG: 384x640 2 cars, 184.4ms
# image 62/90 d:\fiftyone\vid8\test\images\frame_000650.PNG: 384x640 2 cars, 170.0ms
# image 63/90 d:\fiftyone\vid8\test\images\frame_000659.PNG: 384x640 2 cars, 169.5ms
# image 64/90 d:\fiftyone\vid8\test\images\frame_000661.PNG: 384x640 1 car, 167.4ms
# image 65/90 d:\fiftyone\vid8\test\images\frame_000669.PNG: 384x640 1 car, 167.3ms
# image 66/90 d:\fiftyone\vid8\test\images\frame_000678.PNG: 384x640 1 car, 160.9ms
# image 67/90 d:\fiftyone\vid8\test\images\frame_000703.PNG: 384x640 1 car, 208.0ms
# image 68/90 d:\fiftyone\vid8\test\images\frame_000704.PNG: 384x640 1 car, 161.2ms
# image 69/90 d:\fiftyone\vid8\test\images\frame_000711.PNG: 384x640 1 car, 168.4ms
# image 70/90 d:\fiftyone\vid8\test\images\frame_000724.PNG: 384x640 1 car, 167.1ms
# image 71/90 d:\fiftyone\vid8\test\images\frame_000735.PNG: 384x640 1 car, 168.6ms
# image 72/90 d:\fiftyone\vid8\test\images\frame_000739.PNG: 384x640 1 car, 157.2ms
# image 73/90 d:\fiftyone\vid8\test\images\frame_000741.PNG: 384x640 1 car, 165.7ms
# image 74/90 d:\fiftyone\vid8\test\images\frame_000761.PNG: 384x640 1 car, 156.8ms
# image 75/90 d:\fiftyone\vid8\test\images\frame_000772.PNG: 384x640 1 car, 163.0ms
# image 76/90 d:\fiftyone\vid8\test\images\frame_000781.PNG: 384x640 2 cars, 139.4ms
# image 77/90 d:\fiftyone\vid8\test\images\frame_000782.PNG: 384x640 1 car, 157.1ms
# image 78/90 d:\fiftyone\vid8\test\images\frame_000794.PNG: 384x640 2 cars, 172.3ms
# image 79/90 d:\fiftyone\vid8\test\images\frame_000795.PNG: 384x640 2 cars, 157.1ms
# image 80/90 d:\fiftyone\vid8\test\images\frame_000798.PNG: 384x640 2 cars, 156.7ms
# image 81/90 d:\fiftyone\vid8\test\images\frame_000800.PNG: 384x640 2 cars, 157.1ms
# image 82/90 d:\fiftyone\vid8\test\images\frame_000802.PNG: 384x640 2 cars, 148.4ms
# image 83/90 d:\fiftyone\vid8\test\images\frame_000806.PNG: 384x640 2 cars, 141.1ms
# image 84/90 d:\fiftyone\vid8\test\images\frame_000807.PNG: 384x640 2 cars, 183.1ms
# image 85/90 d:\fiftyone\vid8\test\images\frame_000811.PNG: 384x640 2 cars, 156.2ms
# image 86/90 d:\fiftyone\vid8\test\images\frame_000827.PNG: 384x640 2 cars, 157.1ms
# image 87/90 d:\fiftyone\vid8\test\images\frame_000832.PNG: 384x640 3 cars, 146.6ms
# image 88/90 d:\fiftyone\vid8\test\images\frame_000850.PNG: 384x640 3 cars, 156.7ms
# image 89/90 d:\fiftyone\vid8\test\images\frame_000877.PNG: 384x640 1 car, 157.1ms
# image 90/90 d:\fiftyone\vid8\test\images\frame_000895.PNG: 384x640 1 car, 140.9ms
# Speed: 3.0ms preprocess, 173.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
import fiftyone as fo
import numpy as np
import os


def read_yolo_detections_file(filepath):
    detections = []
    if not os.path.exists(filepath):
        return np.array([])

    with open(filepath) as f:
        lines = [line.rstrip('\n').split(' ') for line in f]

    for line in lines:
        detection = [float(l) for l in line]
        detections.append(detection)
    return np.array(detections)


def _uncenter_boxes(boxes):
    '''convert from center coords to corner coords'''
    boxes[:, 0] -= boxes[:, 2]/2.
    boxes[:, 1] -= boxes[:, 3]/2.


def _get_class_labels(predicted_classes, class_list):
    labels = predicted_classes.cpu().numpy().astype(int)
    labels = [class_list[l] for l in labels]
    return labels


def get_prediction_filepath(filepath, result_prediction_path, run_number=1, ):
    run_num_string = ""
    if run_number != 1:
        run_num_string = str(run_number)
    filename = filepath.split("/")[-1].rsplit(".", 1)[0]
    return f"{result_prediction_path}/{filename}.txt"


def convert_yolo_segmentations_to_fiftyone(
    yolo_segmentations,
    class_list
):

    detections = []
    boxes = yolo_segmentations.boxes.xywhn
    if not boxes.shape or yolo_segmentations.masks is None:
        return fo.Detections(detections=detections)

    _uncenter_boxes(boxes)
    masks = yolo_segmentations.masks.data
    labels = _get_class_labels(yolo_segmentations.boxes.cls, class_list)
    confidences = yolo_segmentations.boxes.conf.cpu().numpy().astype(float)
    for label, box, mask, confidence in zip(labels, boxes, masks, confidences):
        # convert to absolute indices to index mask
        w, h = mask.shape
        tmp = np.copy(box)
        tmp[2] += tmp[0]
        tmp[3] += tmp[1]
        tmp[0] *= h
        tmp[2] *= h
        tmp[1] *= w
        tmp[3] *= w
        tmp = [int(b) for b in tmp]
        y0, x0, y1, x1 = tmp
        sub_mask = mask[x0:x1, y0:y1]

        detections.append(
            fo.Detection(
                label=label,
                bounding_box=list(box),
                mask=sub_mask.cpu().numpy().astype(bool),
                confidence=confidence
            )
        )

    return fo.Detections(detections=detections)


def add_yolo_detections(
    samples,
    prediction_field,
    prediction_filepath,
    class_list
):

    prediction_filepaths = samples.values(prediction_filepath)
    # yolo_detections = [read_yolo_detections_file(
    #     pf) for pf in prediction_filepaths]
    yolo_seg_results = results
    segmentations = [convert_yolo_segmentations_to_fiftyone(
        yd, class_list) for yd in yolo_seg_results]
    samples.set_values(prediction_field, segmentations)


# Define the paths to the dataset
dataset_dir = "vid8/test"
data_path = f"{dataset_dir}/images"
labels_path = f"{dataset_dir}/labels"
result_prediction_path = f"{dataset_dir}/prediction"
name_prediction = "model_version_1"
classes = ["car"]

# Load the dataset
dataset = fo.Dataset.from_dir(
    dataset_type=fo.types.YOLOv4Dataset,
    data_path=data_path,
    labels_path=labels_path,
    label_type="polylines",
    classes=['car']
)

filepaths = dataset.values("filepath")
# # For each file path, replace \\ to /
filepaths = [fp.replace("\\", "/") for fp in filepaths]
prediction_filepaths = [get_prediction_filepath(
    fp, result_prediction_path=result_prediction_path) for fp in filepaths]
dataset.set_values(
    "yolov8n_det_filepath",
    prediction_filepaths
)

add_yolo_detections(
    dataset,
    name_prediction,
    "yolov8n_det_filepath",
    classes
)
# Out:
#  100% |███████████████████| 90/90 [1.3s elapsed, 0s remaining, 70.3 samples/s]

# %%
import fiftyone as fo
import numpy as np
import cv2

def polyline_to_mask(polyline, height=1680, width=2992):
    mask = np.zeros((height, width), dtype=np.uint8)
    # Denormalize the points
    points = np.array(polyline.points) * [width, height]
    points = points.astype(np.int32)
    points = points.reshape((-1, 1, 2))
    cv2.fillPoly(mask, [points], 255)
    return mask

def convert_polylines_to_masks(sample, height=1680, width=2992):
    ground_truth = sample["ground_truth"]
    if not hasattr(ground_truth, "polylines"):
        print(f"Sample {sample.id} 'ground_truth' field has no 'polylines'")
        return
    
    new_detections = []
    for polyline in ground_truth.polylines:
        # Convert polyline to mask using default dimensions
        mask = polyline_to_mask(polyline, height, width)
        
        # Compute the bounding box for the polyline
        points = np.array(polyline.points).reshape(-1, 2) * [width, height]
        min_x = int(np.min(points[:, 0]))
        max_x = int(np.max(points[:, 0]))
        min_y = int(np.min(points[:, 1]))
        max_y = int(np.max(points[:, 1]))
        
        bbox = [
            min_x / width,
            min_y / height,
            (max_x - min_x) / width,
            (max_y - min_y) / height
        ]
        
        # Crop the mask to the bounding box
        cropped_mask = mask[min_y:max_y, min_x:max_x]
        # Convert the cropped mask to boolean
        boolean_mask = cropped_mask.astype(bool)
        
        # Create a detection with mask
        new_detection = fo.Detection(label=polyline.label, mask=boolean_mask, bounding_box=bbox)
        new_detections.append(new_detection)
    
    if new_detections:
        sample["predictions"] = fo.Detections(detections=new_detections)
    
    # Delete the ground_truth field after processing
    del sample["ground_truth"]
    sample.save()

# Iterate over each sample to convert polylines to masks
for sample in dataset:
    convert_polylines_to_masks(sample)

# Save the modified dataset
dataset.save()

# %%
detection_results = dataset.evaluate_detections(
    name_prediction,
    eval_key="eval",
    compute_mAP=True,
    gt_field="predictions",
    use_masks=True,
)
# Out:
# Evaluating detections...
#  100% |███████████████████| 90/90 [3.8s elapsed, 0s remaining, 41.9 samples/s]
# Performing IoU sweep...
#  100% |███████████████████| 90/90 [2.8s elapsed, 0s remaining, 46.7 samples/s]

# %%
mAP = detection_results.mAP()
print(f"mAP = {mAP}")
# Out:
# mAP = 0.47933907894669225

# %%
session = fo.launch_app(dataset)
session.wait()
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=c54e6910-9245-495e-9545-9197549a1f0a"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Notebook sessions cannot wait
